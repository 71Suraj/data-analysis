# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(10,2),index=pd.date_range('1/1/2000',periods=10),columns=list(['A','D']))

print(df)

df.plot()
# Out:
#                    A         D
# 2000-01-01 -0.629828  0.249671
# 2000-01-02  1.694192  1.814112
# 2000-01-03 -0.849039  0.100183
# 2000-01-04  0.593980  0.786408
# 2000-01-05 -0.299711 -0.866325
# 2000-01-06 -1.811812 -0.965781
# 2000-01-07  1.645353  1.280261
# 2000-01-08 -0.366587 -1.415465
# 2000-01-09  0.958231  0.555582
# 2000-01-10  0.553749  0.679540
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2000',periods=10),columns=list('ABCD'))

print(df)

df.plot()
# Out:
#                    A         B         C         D
# 2000-01-01  0.414568  1.386519  0.856842 -2.035765
# 2000-01-02  1.001083  0.982169 -0.880395 -0.927062
# 2000-01-03 -0.654030  0.347525  0.201843 -2.011301
# 2000-01-04 -0.433737 -0.412088  0.503782 -1.148542
# 2000-01-05  0.327746  0.041536  0.070143  0.984397
# 2000-01-06 -0.465262 -0.742281 -0.556853 -0.890346
# 2000-01-07 -0.515019  1.850652 -0.414664 -0.755522
# 2000-01-08 -1.762035 -0.985798  0.203984  1.556258
# 2000-01-09 -1.426748  0.543391 -0.951899 -1.264169
# 2000-01-10  0.247060 -0.288023  1.245134 -0.637751
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(10,4),columns=list(['A','B','C','D']))

print(df)

df.plot.bar()
# Out:
#           A         B         C         D
# 0 -0.047392 -0.063375 -0.647457  1.248714
# 1  0.415920 -0.200090  1.431841  0.287775
# 2 -0.731279  1.168451 -1.185933 -0.429504
# 3 -0.584128 -2.242719  0.684769 -0.533768
# 4 -0.810014 -0.306105 -0.743287 -2.351446
# 5 -0.435711  1.248607 -0.444848 -2.972966
# 6  0.878300 -0.167320  0.929002 -0.400647
# 7 -1.541111  1.830788  0.284473 -1.032748
# 8 -0.894775 -0.608600  0.834537 -1.241074
# 9  0.053150 -0.765738 -0.541648  0.089271
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=list(['A','B','C','D']))

print(df)

df.plot.bar()
